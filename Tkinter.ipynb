# %%
import tkinter
window = tkinter.Tk()
window.title("Result Manager GUI")
window.geometry ("400x400")

topic1 = Label(window, text = "Result Manager GUI", font = ("Arial Bold",20),fg="Yellow",bg="blue")
topic2 = Label(window, text = "Subject", font = ("Arial Bold",14),)
topic3 = Label(window, text = "Mark Obtained", font = ("Arial Bold",14))

grade1 = Label(window, text = " ", font = ("Arial Bold",12))
grade2 = Label(window, text = " ", font = ("Arial Bold",12))
grade3 = Label(window, text = " ", font = ("Arial Bold",12))
grade4 = Label(window, text = " ", font = ("Arial Bold",12))

phy = Label(window, text = "Physics", font = ("Arial Bold",12),fg="Red").place(x=0, y=82)
chem = Label(window, text = "Chemistry", font = ("Arial Bold",12),fg="Red").place(x=0, y=107)
math = Label(window, text = "Maths", font = ("Arial Bold",12),fg="Red").place(x=0, y=132)
eng = Label(window, text = "English", font = ("Arial Bold",12),fg="Red").place(x=0, y=156) 

def clicked():
    result1 ="Physics mark is: " + data1.get()
    grade1.configure(text=result1)

    result2 ="Chemistry mark is: " + data2.get()
    grade2.configure(text=result2)    

    result3 ="Maths mark is: " + data3.get()
    grade3.configure(text=result3)

    result4 ="English mark is: " + data4.get()
    grade4.configure(text=result4)

def chk():       
    if chk_state.get() == 1:
        button['state'] = NORMAL
        #button.configure(text="Awake!")

    elif chk_state.get() == 0:
        button['state'] = DISABLED
        #button.configure(text="Sleeping!")
    else:
        messagebox.showerror('PythonGuides', 'Something went wrong!')

chk_state = IntVar()

Check = Checkbutton(window, text = "Above marks are correctly entered.", var = chk_state, onvalue=1, offvalue=0, command=chk)

button = Button(window, text= "Submit Button",font = ("Arial Bold",10),fg="Red", state = DISABLED,command = clicked)

data1 = Entry(window, width="20")
data2 = Entry(window, width="20")
data3 = Entry(window, width="20")
data4 = Entry(window, width="20")

topic1.grid(column =1, row = 0)
topic2.grid(column =0, row =1, pady = 10)
topic3.grid(column =1, row =1)

data1.grid(column =1, row =2)
data2.grid(column =1, row =3,pady = 5)
data3.grid(column =1, row =4)
data4.grid(column =1, row =5,pady = 5)

grade1.grid(column =1, row =8)
grade2.grid(column =1, row =9,pady = 5)
grade3.grid(column =1, row =10)
grade4.grid(column =1, row =11,pady = 5)

Check.grid(column = 1, row = 6, pady = 10)

button.grid(column =1, row =7)

window.mainloop()
