# %%
import tkinter
window = tkinter.Tk()
window.title("Result Calculator GUI")
window.geometry ("400x500")

topic1 = Label(window, text = "Result Calculator GUI", font = ("Arial Bold",20),fg="Yellow",bg="blue")
topic2 = Label(window, text = "Subject", font = ("Arial Bold",14),)
topic3 = Label(window, text = "Mark Obtained", font = ("Arial Bold",14))

mark1 = Label(window, text = " ", font = ("Arial Bold",12))
mark2 = Label(window, text = " ", font = ("Arial Bold",12))
mark3 = Label(window, text = " ", font = ("Arial Bold",12))
mark4 = Label(window, text = " ", font = ("Arial Bold",12))
perc =  Label(window, text = " ", font = ("Arial Bold",12))

grade =  Label(window, text = " ", font = ("Arial Bold",12))

phy = Label(window, text = "Physics", font = ("Arial Bold",12),fg="Red").place(x=0, y=82)
chem = Label(window, text = "Chemistry", font = ("Arial Bold",12),fg="Red").place(x=0, y=107)
math = Label(window, text = "Maths", font = ("Arial Bold",12),fg="Red").place(x=0, y=132)
eng = Label(window, text = "English", font = ("Arial Bold",12),fg="Red").place(x=0, y=156) 

phy_data = Entry(window, width="20")
chem_data = Entry(window, width="20")
math_data = Entry(window, width="20")
eng_data = Entry(window, width="20")

def clicked():
    result1 = f"Physics mark is:{phy_data.get()}"
    mark1.configure(text = result1)

    result2 = f"Chemistry mark is: {chem_data.get()}"
    mark2.configure(text = result2)    

    result3 = f"Maths mark is: {math_data.get()}"
    mark3.configure(text = result3)

    result4 = f"English mark is:{eng_data.get()}"
    mark4.configure(text = result4)
    
    perc_int = ( float(phy_data.get()) + float(chem_data.get()) + float(math_data.get()) + float(eng_data.get()) )
    perc_str = str(perc_int)
    Final = f"Percentage:{perc_str}% "
    perc.configure(text = Final)
    
    if perc_int <= 100 and perc_int >= 90:
        Grade = "Grade: A+"
        grade.configure(text = Grade)
    if perc_int <= 89 and perc_int >= 80:
        Grade = "Grade: A"
        grade.configure(text = Grade)
    if perc_int <= 79 and perc_int >= 70:
        Grade = "Grade: B+"
        grade.configure(text = Grade)
    if perc_int <= 69 and perc_int >= 60:
        Grade = "Grade: B"
        grade.configure(text = Grade)
    if perc_int <= 59 and perc_int >= 50:
        Grade = "Grade: C+"
        grade.configure(text = Grade)
    if perc_int <= 49 and perc_int >= 40:
        Grade = "Grade: C"
        grade.configure(text = Grade)

def chk():       
    if chk_state.get() == 1:
        button['state'] = NORMAL
        #button.configure(text="Awake!")

    elif chk_state.get() == 0:
        button['state'] = DISABLED
        #button.configure(text="Sleeping!")

chk_state = IntVar()
Check = Checkbutton(window, text = "Above marks are correctly entered.", var = chk_state, onvalue=1, offvalue=0, command=chk)

button = Button(window, text= "Submit Button",font = ("Arial Bold",10),fg="Red", state = DISABLED,command = clicked)


topic1.grid(column =1, row = 0)
topic2.grid(column =0, row =1, pady = 10)
topic3.grid(column =1, row =1)

phy_data.grid(column =1, row =2)
chem_data.grid(column =1, row =3,pady = 5)
math_data.grid(column =1, row =4)
eng_data.grid(column =1, row =5,pady = 5)

Check.grid(column = 1, row = 6, pady = 10)

button.grid(column =1, row =7)

mark1.grid(column =1, row =8)
mark2.grid(column =1, row =9, pady = 5)
mark3.grid(column =1, row =10)
mark4.grid(column =1, row =11,pady = 5)
perc.grid(column =1, row =12)
grade.grid (column = 1, row = 13,pady = 5)


window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\neupa\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-485-9049e6d5c22e>", line 41, in clicked
#     perc_int = ( float(phy_data.get()) + float(chem_data.get()) + float(math_data.get()) + float(eng_data.get()) )
# ValueError: could not convert string to float: ''
